# %%
! python3 -m pip install --upgrade pip
! python3 -m pip install --upgrade numpy matplotlib pandas seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np              # біблиотека для аналізу даних
import pandas as pd             # біблиотека для аналізу даних
import matplotlib as mpl
import matplotlib.pyplot as plt # Інтерфейс бібліотеки для візуалізації

# %%
from IPython.display import Image     # Вбудовані функції для зручної роботи
Image(url='https://matplotlib.org/stable/_static/logo2_compressed.svg')
# Out:
# <img src="https://matplotlib.org/stable/_static/logo2_compressed.svg"/>

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.

# %%
weather = pd.read_csv('../datasets/seattleWeather.csv', parse_dates=['DATE'], index_col='DATE')
weather['TAVG'] = weather[['TMAX', 'TMIN']].mean(axis=1)
iris = pd.read_csv('../datasets/iris.csv', index_col='Id')
flights = pd.read_csv('../datasets/flights.csv')
mtcars = pd.read_csv('../datasets/mtcars.csv')

xs = np.linspace(0, 2, 100)
df = pd.DataFrame({'x': xs, 'y': xs, 'y2': xs ** 2, 'y3': xs ** 3})
df.head(3)
# Out:
#           x         y        y2        y3
# 0  0.000000  0.000000  0.000000  0.000000
# 1  0.020202  0.020202  0.000408  0.000008
# 2  0.040404  0.040404  0.001632  0.000066

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# ## Архітектура
# **Matplotlib** має три основних шари:
# * Шар нижнього рівня (backend);
# * Шар малюнків;
# * Шар скриптів;
#
# **Шар нижнього рівня** містить три інтерфейсних класи:
# * _figure canvas_ - канва малюнка, що визначає область малюнка;
# * _renderer_, що малює на канві;
# * _event_, що обробляє ввод користувача.
#
# **Шар малюнків** малює на канві за допомогою Renderer'а.
# Все, що знаходиться на малюнку Matplotlib, є екземпляром шару малюнка. Заголовок, мітки – індивидуальні об'єкти шару малюнків.
#
# **Шар скриптів** це полегшений верхньорівневий інтерфейс

# %% [markdown]
# ## Терміни

# %%
Image(url='https://matplotlib.org/stable/_images/anatomy.png')
# Out:
# <img src="https://matplotlib.org/stable/_images/anatomy.png"/>

# %% [markdown]
# * **Figure**
# Весь малюнок, де відображаються дані (окреме вікно, Jupyter-віджет, т.п.).
# Figure має один або більше дочірніх графіка - Axes.
#
# * **Axes**
# Власне окремий графік - область, де точка має координати x-y або x-y-z.
# Axes містить два, або три Axis
#
# * **Axis**
# Вісь графіка
#
# * **Artist**
# Все, що є на малюнку є об'єктом класу Artist, навіть Figure, Axes, і Axis, а також Text, Line2D і т.д.

# %% [markdown]
# ## Налаштування

# %% [markdown]
# #### Бекенди
# Програмі засоби, за допомогою яких малюється графік
# https://matplotlib.org/stable/tutorials/introductory/usage.html#backends

# %%
# Бекенди matplotlib
mpl.rcsetup.all_backends
# Out:
# ['GTK3Agg',
#  'GTK3Cairo',
#  'MacOSX',
#  'nbAgg',
#  'Qt4Agg',
#  'Qt4Cairo',
#  'Qt5Agg',
#  'Qt5Cairo',
#  'TkAgg',
#  'TkCairo',
#  'WebAgg',
#  'WX',
#  'WXAgg',
#  'WXCairo',
#  'agg',
#  'cairo',
#  'pdf',
#  'pgf',
#  'ps',
#  'svg',
#  'template']

# %%
# Вибір бекенду
mpl.use('nbAgg')

# %%
# Бекенди matplotlib в IPython
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# Вибір бекенду в IPython
# %matplotlib inline

# %%
# Поточний бекенд
mpl.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %% [markdown]
# #### Інтерактивний режим
# Малює графік відразу, не чекаючи команди `plt.show()`
# https://matplotlib.org/stable/tutorials/introductory/usage.html#what-is-interactive-mode

# %%
mpl.is_interactive()
# Out:
# True

# %%
mpl.interactive(False) # plt.ioff()

# %%
mpl.interactive(True) # plt.ion()

# %% [markdown]
# #### Стилі
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Використати певний стиль графіків
plt.style.use('default')
sinplot()

# %%
# Тимасовий стиль графіків
with plt.style.context('ggplot'):
    sinplot()

# %% [markdown]
# #### Палітри
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %%
# plt.cm.register_cmap() 
plt.cm.get_cmap() 
# mpl.cm.viridis

# %%
from operator import attrgetter
for cmap in plt.colormaps():
    display(attrgetter(cmap)(plt.cm))
    break

# %%
plt.set_cmap('viridis')
#plt.rcParams['image.cmap'] = 'jet'
sinplot()

# %% [markdown]
# #### Розмір

# %%
# figure size in inches
plt.rcParams['figure.figsize'] = (6.4, 4.8)

# %% [markdown]
# ### Як побудувати графік?

# %%
# Pyplot-style
plt.figure(figsize=[6.4, 4.8])
plt.plot(df.x, df.y, label='linear')  # Plot some data on the axes.
plt.plot(df.x, df.y2, label='quadratic')  # Plot more data on the axes...
plt.plot('x', 'y3', '', label='cubic', data=df)  # ... and some more.
plt.xlabel('x label')  # Add an x-label to the axes.
plt.ylabel('y label')  # Add a y-label to the axes.
plt.title("Simple Plot")  # Add a title to the axes.
plt.xlim((0, 2.1)) # Set x-axis limits
plt.ylim(0, 8.5)  # Set y-axis limits
#plt.axis([0, 2.1, 0, 8.5]) # Set axis' limits
plt.legend()  # Add a legend.
plt.grid()
# plt.savefig('image.png', dpi=300)
plt.show()

# %%
# OOP-style
# ax = plt.gca() # Get the current Axes instance on the current figure
# fig = plt.figure(figsize=[6.4, 4.8])
# ax = fig.add_subplot(nrows=1, ncols=1, index=1)

fig, ax = plt.subplots(figsize=[6.4, 4.8], nrows=1, ncols=1, sharex=False, sharey=False)  # Create a figure and an axes.
ax.plot(df.x, df.y, label='linear')  # Plot some data on the axes.
ax.plot(df.x, df.y2, label='quadratic')  # Plot more data on the axes...
ax.plot('x', 'y3', '', label='cubic', data=df)  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.set_xlim(0, 2.1)
ax.set_ylim(0, 8.5)
ax.legend()  # Add a legend.
ax.grid() # Add grid

#fig.savefig('image.png', dpi=300)
plt.show()

# %%
# Pandas-style
ax = df.plot(kind='line', 
             figsize=[6.4, 4.8], 
             title="Simple Plot", 
             xlim=[0, 2.1],
             ylim=(0, 8.5),
             legend=True, 
             grid=True, 
             x='x', 
#              subplots=True
            )
#ax.figure.savefig('image.png', dpi=300)
plt.show()

# %% [markdown]
# ### Типи графіків
# * **plot()** - базовий, **швидкий** line/scatter
# * **scatter()** - точковий графік (повільніший)
# * **bar() / barh()** - стовпчикова діаграмма
# * **pie()** - секторна діаграмма
# * **hist()** - гістограмма
# * **table()** - відображення таблиці на графіку
# * **polar()** - полярний графік
# * **imshow()** - відображення массивів пікселів
# * **pcolor() / pcolormesh()** - heatmap-подібний графік
# * **contour() / contourf()** - контурний графік
# * **arrow()** - стрілка
# * **quiver()** - поле векторів
# * **streamplot()** - поток векторів
# * **semilogx() / semilogy() / loglog()** - створення логарифмічних графіків
# ### Додаткові функції
# * **fill()** - відображення замкнених полігональних структур
# * **fill_between()** - заповнює область між двома горизонтальними лініями
# * **fill_betweenx()** - заповнює область між двома вертикальними лініями
# * **axhspan()** - додає горизонтальний заповнений прямокутник
# * **axvspan()** - додає вертикальний заповнений прямокутник
# * **axhline()** - додає горизонтальну лінію
# * **axvline()** - додає вертикальну лінію
# * **legend()** - автоматичне створення легенди
# * **grid()** - створення сітки на графіку

# %% [markdown]
# ### Plot
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.figure(figsize=[6.4, 4.8])

# One plot
# plt.plot(df.x, df.y2, 'go--', linewidth=2, markersize=6)
# plt.plot(df.x, df.y2, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=5)

# Few plots - one call
# plt.plot(df.x, df[['y','y2','y3']], 'r--')
# plt.plot(df.x, df.y, 'r--', df.x, df.y2, 'bs', df.x, df.y3, 'g^')

# Few plots - few calls
plt.plot(df.x, df.y, 'r--', label='linear')
plt.plot(df.x, df.y2, 'bs', label='quadratic')
plt.plot(df.x, df.y3, 'g^', label='cubic')
plt.legend()

plt.show()

# %% [markdown]
# Cтрока формату графіку (підходять символи, що відммічені жирним шрифтом)
# `fmt = '[marker][line][color]'`

# %% [markdown]
# #### Маркери
# https://matplotlib.org/stable/api/markers_api.html
# * **'.'** - point
# * **','** - pixel
# * **'o'** - circle
# * **'v'** - triangle_down
# * **'^'** - triangle_up
# * **'<'** - triangle_left
# * **'>'** - triangle_right
# * **'1'** - tri_down
# * **'2'** - tri_up
# * **'3'** - tri_left
# * **'4'** - tri_right
# * **'8'** - octagon
# * **'s'** - square
# * **'p'** - pentagon
# * **'P'** - plus (filled)
# * **'*'** - star
# * **'h'** - hexagon1
# * **'H'** - hexagon2
# * **'+'** - plus
# * **'x'** - x
# * **'X'** - x (filled)
# * **'D'** - diamond
# * **'d'** - thin_diamond
# * **'|'** - vline
# * **'_'** - hline

# %% [markdown]
# #### Стилі ліній
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# * **'-'** / 'solid' - суцільна лінія
# * **'--'** / 'dashed' - штрихова лінія
# * **':'** / 'dotted' - пунктирна лінія
# * **'-.'** / 'dashdot' - штрихпунктирна лінія
# * **' '** / **''** / None - відсутня лінія
# * `(offset, (on_off_seq))` - складна лінія
# Наприклад `(0, (3, 10, 1, 15))` означає (3pt line, 10pt space, 1pt line, 15pt space) with no offset

# %% [markdown]
# #### Кольори
# https://matplotlib.org/stable/api/colors_api.html
# * одна з букв {**'b'**, **'g'**, **'r'**, **'c'**, **'m'**, **'y'**, **'k'**, **'w'**},
# що є скороченнями blue, green, red, cyan, magenta, yellow, black, white.
# * RGB / RGBA (red, green, blue, alpha) в інтервалі [0, 1] - **(0.1, 0.2, 0.5)** або (0.1, 0.2, 0.5, 0.3);
# * hex RGB / RGBA строка - **'#0f0f0f'** або '#0f0f0f80';
# * скорочена hex RGB / RGBA строка - **'#abc'** == '#aabbcc';
# * відтінки сірого, що представлені у вигляді числа в інтервалі [0, 1] - **'0.5'**;
# * назва кольору в X11/CSS4 - **'Aquamarine'**;
# * назва кольору в xkcd з префіксом - **'xkcd:sky blue'**;
# * назва кольору в Tableau 'T10' categorical palette - **'tab:olive'**;

# %% [markdown]
# ### Scatter
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
plt.figure(figsize=(8,6))
plt.scatter(x='PetalLengthCm', y='PetalWidthCm', marker='p', data=iris)
plt.show()

# %%
iris['SpeciesColor'] = iris['Species'].map({'Iris-setosa': 'y', 'Iris-versicolor': 'r', 'Iris-virginica': 'b'})
iris['SepalArea'] = iris['SepalLengthCm'] * iris['SepalWidthCm']

plt.figure(figsize=(9,6))
plt.scatter(x='PetalLengthCm', y='PetalWidthCm', c='SpeciesColor', s='SepalArea', data=iris)
plt.show()

# %% [markdown]
# ### Bar
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %%
cyl6 = mtcars[mtcars['cyl'] == 6]
plt.figure(figsize=(12,6))
#plt.bar(x='model', height='hp', label='HP', color=list('rgbkymc'), data=cyl6)
plt.bar(x='model', height='disp', label='Disp', bottom=cyl6.hp, data=cyl6)
plt.legend()
plt.show()

# %%
cyl8 = mtcars[mtcars['cyl'] == 8]
plt.figure(figsize=(9,6))
plt.barh(y='model', width='qsec', xerr='wt', data=cyl8, color=mpl.cm.Paired.colors)
plt.show()

# %% [markdown]
# ### Pie
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
duration = flights.groupby('carrier', as_index=False).agg({'duration': 'sum'})
duration['is_ua'] = duration['carrier'].eq('UA').astype(int).div(4)

def pct_formatter(pct: float):
    #return format(pct, '.2f')
    return duration['duration'].mul(pct).div(100).sum().round(1)

plt.figure(figsize=(9,6))
plt.pie(x='duration', explode=duration.is_ua, labels='carrier', autopct=pct_formatter, shadow=True, data=duration)
plt.legend()
plt.show()

# %% [markdown]
# ### Imshow
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
corrs = iris.corr(method='kendall')
display(corrs)

plt.figure(figsize=(9,6))
plt.imshow(corrs, cmap='winter')
plt.xticks(np.arange(corrs.columns.size), corrs.columns)
plt.yticks(np.arange(corrs.index.size), corrs.index)

for i, (x, row) in enumerate(corrs.iterrows()):
    for j, (y, value) in enumerate(row.iteritems()):
        plt.text(i, j, round(value, 2))
        
plt.colorbar()
plt.show()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.138613       0.660313      0.550783
# SepalWidthCm       -0.138613      1.000000      -0.205548     -0.211812
# PetalLengthCm       0.660313     -0.205548       1.000000      0.693244
# PetalWidthCm        0.550783     -0.211812       0.693244      1.000000
# SepalArea           0.489933      0.429441       0.329396      0.294318
#
#                SepalArea
# SepalLengthCm   0.489933
# SepalWidthCm    0.429441
# PetalLengthCm   0.329396
# PetalWidthCm    0.294318
# SepalArea       1.000000

# %% [markdown]
# ### Pcolormesh
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pcolormesh.html

# %%
corrs = iris.corr(method='spearman')
display(corrs)
std = iris.std().reset_index(drop=True)
std_cum = pd.concat([pd.Series([0]), std],ignore_index=True).cumsum()
display(std)

plt.figure(figsize=(9,7))
plt.pcolormesh(std_cum, std_cum, corrs, shading='auto', cmap='seismic')

#plt.xticks(std_cum.add(std.div(2)).dropna(), corrs.columns)
#plt.yticks(std_cum.add(std.div(2)).dropna(), corrs.columns)

plt.colorbar()

for i, (x, row) in enumerate(corrs.iterrows()):
    for j, (y, value) in enumerate(row.iteritems()):
        plt.text(i+0.5, j+0.5, round(value, 2))

plt.show()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.159457       0.881386      0.834421
# SepalWidthCm       -0.159457      1.000000      -0.303421     -0.277511
# PetalLengthCm       0.881386     -0.303421       1.000000      0.936003
# PetalWidthCm        0.834421     -0.277511       0.936003      1.000000
# SepalArea           0.665131      0.592384       0.458859      0.442404
#
#                SepalArea
# SepalLengthCm   0.665131
# SepalWidthCm    0.592384
# PetalLengthCm   0.458859
# PetalWidthCm    0.442404
# SepalArea       1.000000
# <ipython-input-33-6c464669177e>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std = iris.std().reset_index(drop=True)
# 0    0.828066
# 1    0.433594
# 2    1.764420
# 3    0.763161
# 4    3.368693
# ...

# %% [markdown]
# ### Box
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
floats = iris.select_dtypes(float)

plt.figure(figsize=(9,7))
plt.boxplot(floats)

plt.xticks(range(1, floats.columns.size + 1), floats.columns)
plt.title('Distribution')
plt.show()

# %% [markdown]
# ### Hist
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
# histtype = {**'bar'**, 'barstacked', 'step', 'stepfilled'},
plt.figure(figsize=(9,6))
plt.hist(flights['delay'], bins=100, range=(-100, 500),  
         histtype='bar', density=False, cumulative=False,
#          weights=flights['delay'].fillna(0).div(flights['duration']).mul(100).abs(),
        )
plt.show()

# %% [markdown]
# ### Кастомізація вісей
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html

# %%
cyl8 = mtcars[mtcars['cyl'] == 8]
plt.figure(figsize=(9,6))
plt.barh(y='model', width='qsec', color=list('rgbkymc'), data=cyl8)
plt.xticks(ticks=range(0,20))
plt.show()

# %%
cyl8 = mtcars[mtcars['cyl'] == 8]
plt.figure(figsize=(12,6))
plt.bar(x='model', height='hp', color=list('rgbkymc'), data=cyl8)
plt.xticks(font='Arial', size=14, rotation='vertical') # ax.set_tick_params(axis='x', ...)
plt.show()

# %% [markdown]
# ### Анотація
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html

# %%
plt.figure(figsize=(9,6))
plt.hist(flights['delay'], bins=100, range=(-100, 550))
plt.annotate('Шо це?', xy=[10,12000], xytext=[50,20000], arrowprops={'arrowstyle': '->', 'color': 'red'})
plt.annotate('The Federal Aviation Administration (FAA)\nconsiders a flight to be delayed\nwhen it is 15 minutes later than its scheduled time',[200, 25000])
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/tutorials/text/annotations.html

# %% [markdown]
# ### Комбіновані графіки

# %%
data = weather[['PRCP', 'TAVG']].resample('6M').mean().reset_index()

fig, ax = plt.subplots()
ax.plot('DATE', 'TAVG', data=data)
ax.plot('DATE', 'PRCP', data=data)
ax.legend()
plt.show()

# %%
data = weather[['PRCP', 'TAVG']].resample('6M').mean().reset_index()

fig, ax = plt.subplots()
ax.set_xlabel('Year')

ax.plot('DATE', 'TAVG', label='Temperature', color='blue', data=data)
ax.set_ylabel('Mean temperature', color='blue')
ax.tick_params('y', colors='blue')
ax.legend()

ax2 = ax.twinx()

ax2.plot('DATE', 'PRCP', label='Precipitation', color='orange', data=data)
ax2.set_ylabel('Mean precipitation', color='orange')
ax2.tick_params('y', colors='orange')
ax2.legend()

plt.show()

# %% [markdown]
# ### Комбіновані графіки

# %%
pie = weather.groupby('RAIN', as_index=False).agg({'PRCP': 'count'})
line = weather[['TMAX', 'TMIN', 'TAVG']].resample('1Y').mean().reset_index()
scatter = weather.assign(RAINcolor=weather['RAIN'].map({True: 'aqua', False: 'chartreuse', np.nan: 'moccasin'}))

fig, axes = plt.subplots(figsize=(14,10), nrows=2, ncols=2)

axes[0,0].pie(x='PRCP', labels='RAIN', autopct='%.2f', pctdistance=0.5, labeldistance=1.2, startangle=45, textprops={'size': 14}, data=pie)
axes[0,0].set_title('Rainy days')

axes[0,1].plot('DATE', 'TAVG', data=line)
axes[0,1].fill_between(x='DATE', y1='TMIN', y2='TMAX', alpha=0.3, data=line)
axes[0,1].set_title('Mean year temperature')
axes[0,1].set_xlabel('Year')
axes[0,1].xaxis.set_major_locator(mpl.dates.YearLocator(base=5))
axes[0,1].xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
axes[0,1].xaxis.set_tick_params(size=14, rotation=45)
axes[0,1].set_ylabel('Degrees, F')
axes[0,1].set_yticks(range(40, 66, 2))
axes[0,1].grid()

axes[1,0].hist(x='PRCP', bins=np.arange(0, 4, 0.2), histtype='step', data=weather)
axes[1,0].set_title('Precipitation distribution')
axes[1,0].set_xlabel('Precipitation')
axes[1,0].set_xticks(np.arange(0, 4, 0.1), minor=True)
axes[0,1].set_ylabel('Days')
axes[1,0].set_yscale('log')

axes[1,1].scatter(x='TAVG', y='PRCP', c='RAINcolor', data=scatter)
axes[1,1].set_title('Temperature and precipitation')
axes[1,1].set_xlabel('Degrees, F')
axes[1,1].set_xticks(range(10, 95, 5))
axes[1,1].set_xticks(range(10, 95, 1), minor=True)
axes[1,1].set_ylabel('Precipitation')
axes[1,1].set_yticks(np.arange(0, 5.2, .5))
axes[1,1].axvline(50, color='red')
axes[1,1].axvspan(30, 70, color='blue', alpha=.2)
axes[1,1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ще раз про збереження графіків

# %%
# fig.savefig('graph.svg')
# fig.savefig('graph.png', dpi=300)
# fig.savefig('graph.jpg', dpi=300, pil_kwargs={'quality': 50})

# %% [markdown]
# #### Тривимірні графіки
# https://matplotlib.org/stable/api/toolkits/mplot3d.html

# %% [markdown]
# #### Анімація
# https://matplotlib.org/stable/api/animation_api.html

# %% [markdown]
# ## Матеріали
# * https://proglib.io/p/vasha-povsednevnaya-shpargalka-po-matplotlib-2021-02-04
# * https://matplotlib.org/stable/tutorials/introductory/usage.html
# * **https://pyprog.pro/mpl/mpl_short_guide.html**
# * https://learn.datacamp.com/courses/introduction-to-data-visualization-with-matplotlib
